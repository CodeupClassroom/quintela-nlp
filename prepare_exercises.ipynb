# %% [markdown]
# # Data Preparation Exercises
#
# ## Imports

# %%
# unicode, regex, json for text digestion
import unicodedata
import re
import json

# nltk: natural language toolkit -> tokenization, stopwords
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

# pandas dataframe manipulation, acquire script, time formatting
import pandas as pd
import acquire
from time import strftime

# shh, down in front
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Exercises
#
# The end result of this exercise should be a file named `prepare.py` that defines the requested functions.
#
# In this exercise we will be defining some functions to prepare textual data. These functions should apply equally well to both the codeup blog articles and the news articles that were previously acquired.
#
# ### 1. Define a function named `basic_clean`. It should take in a string and apply some basic text cleaning to it:
#
# * Lowercase everything
# * Normalize unicode characters
# * Replace anything that is not a letter, number, whitespace or a single quote.

# %%
# we will define a basic_clean function for a single document (one string)
def basic_clean(string):
    '''
    This function takes in a string and
    returns the string normalized.
    '''
    # we will normalize our data into standard NFKD unicode, feed it into an ascii encoding
    # decode it back into UTF-8
    string = unicodedata.normalize('NFKD', string)\
             .encode('ascii', 'ignore')\
             .decode('utf-8', 'ignore')
    # utilize our regex substitution to remove our undesirable characters, then lowercase
    string = re.sub(r"[^\w0-9'\s]", '', string).lower()
    return string

# %% [markdown]
# ### 2. Define a function named `tokenize`. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(string):
    '''
    This function takes in a string and
    returns a tokenized string.
    '''
    # make our tokenizer, taken from nltk's ToktokTokenizer
    tokenizer = nltk.tokenize.ToktokTokenizer()
    # apply our tokenizer's tokenization to the string being input, ensure it returns a string
    string = tokenizer.tokenize(string, return_str = True)
    
    return string

# %% [markdown]
# ### 3. Define a function named `stem`. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(string):
    '''
    This function takes in a string and
    returns a string with words stemmed.
    '''
    # create our stemming object
    ps = nltk.porter.PorterStemmer()
    # use a list comprehension => stem each word for each word inside of the entire document,
    # split by the default, which are single spaces
    stems = [ps.stem(word) for word in string.split()]
    # glue it back together with spaces, as it was before
    string = ' '.join(stems)
    
    return string

# %% [markdown]
# ### 4. Define a function named `lemmatize`. It should accept some text and return the text after applying lemmatization to each word.

# %%
def lemmatize(string):
    '''
    This function takes in string for and
    returns a string with words lemmatized.
    '''
    # create our lemmatizer object
    wnl = nltk.stem.WordNetLemmatizer()
    # use a list comprehension to lemmatize each word
    # string.split() => output a list of every token inside of the document
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    # glue the lemmas back together by the strings we split on
    string = ' '.join(lemmas)
    #return the altered document
    return string

# %% [markdown]
# ### 5. Define a function named `remove_stopwords`. It should accept some text and return the text after removing all the stopwords.
#
# ### This function should define two optional parameters, `extra_words` and `exclude_words`. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
list1 = [1, 2, 3, 4]
list2 = [2, 1, 3, 4]

print(set(list1)==set(list2))
# Out:
# True

# %%
list1 == list2
# Out:
# False

# %%
mylist = ['a', 'b', 'c', 'c', 'd']

myset = set(mylist)

print(mylist, myset)
# Out:
# ['a', 'b', 'c', 'c', 'd'] {'d', 'c', 'b', 'a'}

# %%
def remove_stopwords(string, extra_words = [], exclude_words = []):
    '''
    This function takes in a string, optional extra_words and exclude_words parameters
    with default empty lists and returns a string.
    '''
    # assign our stopwords from nltk into stopword_list
    stopword_list = stopwords.words('english')
    # utilizing set casting, i will remove any excluded stopwords
    stopword_set = set(stopword_list) - set(exclude_words)
    # add in any extra words to my stopwords set using a union
    stopword_set = stopword_set.union(set(extra_words))
    # split our document by spaces
    words = string.split()
    # every word in our document, as long as that word is not in our stopwords
    filtered_words = [word for word in words if word not in stopword_set]
    # glue it back together with spaces, as it was so it shall be
    string_without_stopwords = ' '.join(filtered_words)
    # return the document back
    return string_without_stopwords

# %% [markdown]
# ### 6. Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe `news_df`.

# %%
news_df = acquire.get_news_articles_data()
news_df
# Out:
#                                                 title  \
# 0   Cybersecurity firm Secureworks to lay off 15% ...
# 1       UK basic wage growth hits record high of 7.8%
# 2             Nigeria inflation rises to 18-year high
# 3   Gangwal to sell IndiGo stake worth $450 mn via...
# 4   No proposal to restrict more electronics' impo...
# 5   Infosys, Liberty Global ink $1.6-bn deal to sc...
# 6   Cello World files IPO papers with SEBI to rais...
# 7   Binance files for protective order against US SEC
# 8   India taking part in global economy brought st...
# 9   Michael Burry's Scion exits Alibaba, JD.com st...
# 10  Paper I've been reading since childhood now po...
# 11  It hurt a lot: Cummins on his wrist injury dur...
# 12  Very delighted for Shaw who's seen plenty of u...
# 13  Some viewers were more interested in WPL than ...
# 14  Chris Woakes, Ashleigh Gardner named ICC Playe...
# 15  MS Dhoni hoists Tricolour at his farmhouse in ...
# 16  Rishabh Pant says 'Do not miss enjoyment in li...
# 17  Sciver-Brunt 1st woman to hit 4 straight sixes...
# 18  West Ham cancels deal to sign ex-Utd captain H...
# 19  18 yrs since Ponting's 156 which is the knock ...
# 20  Cybersecurity firm Secureworks to lay off 15% ...
# 21  X scales down ad unit generating $100 million ...
# 22  No proposal to restrict more electronics' impo...
# 23  Infosys, Liberty Global ink $1.6-bn deal to sc...
# 24  Sundar Pichai wishes India on I-Day, shares 't...
# 25  Amazon exec running Alexa, Echo to step down a...
# 26  iPhone 14 series users report battery health i...
# 27  PayPal appoints Intuit exec Alex Chriss as new...
# 28  India working on 6G launch, task force created...
# 29  Tier-2, 3 cities' youth are writing India's di...
# 30  I'm not good but I've to be: Bruce Willis' wif...
# 31  Shilpa replies to criticism for wearing shoes ...
# 32  We've nothing left because you left us: Ankita...
# 33  My job is to give a hit to throw Aaliyah a gra...
# 34  Had initially said no to the show: 'Bigg Boss ...
# 35  Never crossed my boundary with anyone on Bigg ...
# 36  Shah Rukh Khan hoists tricolour at Mannat; sha...
# 37  Margot Robbie expected to earn ₹416 crore thro...
# 38  I told myself I look ugly & nobody would look ...
# 39  Most men can't deal with attraction towards tr...
#
#                                               content       category
# 0   Secureworks said it will lay off 15% of its wo...       business
# 1   Basic wages in UK hit a new record growth rate...       business
# 2   Nigeria's annual inflation rose to its highest...       business
# 3   Indigo airline promoter Gangwal family led by ...       business
# 4   There's no proposal at present to impose impor...       business
# 5   Infosys and Liberty Global announced a five-ye...       business
# 6   Household products maker Cello World has filed...       business
# 7   Binance filed for a protective court order aga...       business
# 8   Prime Minister Narendra Modi said India's part...       business
# 9   Michael Burry's Scion Asset Management exited ...       business
# 10  Ex-India captain Virat Kohli took to his Insta...         sports
# 11  Discussing the wrist injury he suffered during...         sports
# 12  India all-rounder Ravichandran Ashwin said he ...         sports
# 13  India captain Harmanpreet Kaur said the 2023 W...         sports
# 14  England fast bowler Chris Woakes and Australia...         sports
# 15  Former Team India captain Mahendra Singh Dhoni...         sports
# 16  A video of Rishabh Pant's speech on Independen...         sports
# 17  English all-rounder Nat Sciver-Brunt became th...         sports
# 18  West Ham have reportedly called off their £30 ...         sports
# 19  Ex-Australia captain Ricky Ponting helped Aust...         sports
# 20  Secureworks said it will lay off 15% of its wo...     technology
# 21  X (formerly Twitter) has started depreciating ...     technology
# 22  There's no proposal at present to impose impor...     technology
# 23  Infosys and Liberty Global announced a five-ye...     technology
# 24  Google's India-born CEO Sundar Pichai on Tuesd...     technology
# 25  Amazon devices head David Limp will step down ...     technology
# 26  Apple's iPhone 14 and iPhone 14 Pro users are ...     technology
# 27  PayPal has named software firm Intuit's senior...     technology
# 28  Addressing the nation on the 77th Independence...     technology
# 29  The youth from Tier-2 and 3 cities are writing...     technology
# 30  Bruce Willis' wife Emma Heming Willis broke do...  entertainment
# 31  Shilpa Shetty responded to criticism after a v...  entertainment
# 32  Actress Ankita Lokhande, in her latest Instagr...  entertainment
# 33  Anurag Kashyap, talking about his daughter Aal...  entertainment
# 34  'Bigg Boss OTT 2' winner Elvish Yadav revealed...  entertainment
# 35  Manisha Rani, who was a part of 'Bigg Boss OTT...  entertainment
# 36  Actor Shah Rukh Khan hoisted the tricolour at ...  entertainment
# 37  According to Variety, actress Margot Robbie is...  entertainment
# 38  Dolly Singh said she always wanted to become a...  entertainment
# 39  Trans actress Trinetra Haldar said men objecti...  entertainment

# %% [markdown]
# ### 7. Make another dataframe for the Codeup blog posts. Name the dataframe `codeup_df`.

# %%
codeup_df = acquire.get_blog_articles_data()
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                              content
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
# 5  Black excellence in tech: Panelist Spotlight –...

# %% [markdown]
# ### 8. For each dataframe, produce the following columns:
#
# * `title` to hold the title
# * `original` to hold the original article/post content
# * `clean` to hold the normalized and tokenized original with the stopwords removed.
# * `stemmed` to hold the stemmed version of the cleaned data.
# * `lemmatized` to hold the lemmatized version of the cleaned data.

# %%
# what we want:
#  -clean: normalized/tokenized, with stopwords removed
#         apply: basic_clean, tokenize, remove_stopwords
#  -stemmed: stemmed version of cleaned data
            # apply: stem function onto cleaned data
#  -lemmatized: lemmatized version of cleaned data
            # apply: lemmatize function onto cleaned datas

# %%
# df['some_col'] = df['old_col'].apply(some_function)

# %%
news_df.rename(columns={'content': 'original'}, inplace=True)
codeup_df.rename(columns={'content': 'original'}, inplace=True)

# %%
news_df
# Out:
#                                                 title  \
# 0   Cybersecurity firm Secureworks to lay off 15% ...
# 1       UK basic wage growth hits record high of 7.8%
# 2             Nigeria inflation rises to 18-year high
# 3   Gangwal to sell IndiGo stake worth $450 mn via...
# 4   No proposal to restrict more electronics' impo...
# 28  Addressing the nation on the 77th Independence...     technology
# 29  The youth from Tier-2 and 3 cities are writing...     technology
# 30  Bruce Willis' wife Emma Heming Willis broke do...  entertainment
# 31  Shilpa Shetty responded to criticism after a v...  entertainment
# 32  Actress Ankita Lokhande, in her latest Instagr...  entertainment
# 33  Anurag Kashyap, talking about his daughter Aal...  entertainment
# 34  'Bigg Boss OTT 2' winner Elvish Yadav revealed...  entertainment
# 35  Manisha Rani, who was a part of 'Bigg Boss OTT...  entertainment
# 36  Actor Shah Rukh Khan hoisted the tricolour at ...  entertainment
# 37  According to Variety, actress Margot Robbie is...  entertainment
# 38  Dolly Singh said she always wanted to become a...  entertainment
# 39  Trans actress Trinetra Haldar said men objecti...  entertainment

# %%
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                             original
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
# 5  Black excellence in tech: Panelist Spotlight –...

# %%
def prep_article_data(df, column, extra_words=[], exclude_words=[]):
    '''
    This function take in a df and the string name for a text column with 
    option to pass lists for extra_words and exclude_words and
    returns a df with the text article title, original text, stemmed text,
    lemmatized text, cleaned, tokenized, & lemmatized text with stopwords removed.
    '''
    df['clean'] = df[column].apply(basic_clean)\
                            .apply(tokenize)\
                            .apply(remove_stopwords,
                                  extra_words=extra_words,
                                  exclude_words=exclude_words)
    
    df['stemmed'] = df['clean'].apply(stem)
    
    df['lemmatized'] = df['clean'].apply(lemmatize)
    
    return df[['title', column,'clean', 'stemmed', 'lemmatized']]

# %%
prep_article_data(news_df, 'original', extra_words = ['ha'], exclude_words = ['no'])
# Out:
#                                                 title  \
# 0   Cybersecurity firm Secureworks to lay off 15% ...
# 1       UK basic wage growth hits record high of 7.8%
# 2             Nigeria inflation rises to 18-year high
# 3   Gangwal to sell IndiGo stake worth $450 mn via...
# 4   No proposal to restrict more electronics' impo...
# 5   Infosys, Liberty Global ink $1.6-bn deal to sc...
# 6   Cello World files IPO papers with SEBI to rais...
# 7   Binance files for protective order against US SEC
# 8   India taking part in global economy brought st...
# 9   Michael Burry's Scion exits Alibaba, JD.com st...
# 10  Paper I've been reading since childhood now po...
# 11  It hurt a lot: Cummins on his wrist injury dur...
# 12  Very delighted for Shaw who's seen plenty of u...
# 13  Some viewers were more interested in WPL than ...
# 14  Chris Woakes, Ashleigh Gardner named ICC Playe...
# 15  MS Dhoni hoists Tricolour at his farmhouse in ...
# 16  Rishabh Pant says 'Do not miss enjoyment in li...
# 17  Sciver-Brunt 1st woman to hit 4 straight sixes...
# 18  West Ham cancels deal to sign ex-Utd captain H...
# 19  18 yrs since Ponting's 156 which is the knock ...
# 20  Cybersecurity firm Secureworks to lay off 15% ...
# 21  X scales down ad unit generating $100 million ...
# 22  No proposal to restrict more electronics' impo...
# 23  Infosys, Liberty Global ink $1.6-bn deal to sc...
# 24  Sundar Pichai wishes India on I-Day, shares 't...
# 25  Amazon exec running Alexa, Echo to step down a...
# 1   basic wage uk hit new record growth rate 78 fu...
# 2   nigeria ' annual inflation rose highest level ...
# 3   indigo airline promoter gangwal family led rak...
# 4   ' no proposal present impose import restrictio...
# 5   infosys liberty global announced fiveyear agre...
# 6   household product maker cello world filed draf...
# 7   binance filed protective court order u securit...
# 8   prime minister narendra modi said india ' part...
# 9   michael burry ' scion asset management exited ...
# 10  exindia captain virat kohli took instagram sto...
# 11  discussing wrist injury suffered fifth ash 202...
# 12  india allrounder ravichandran ashwin said deli...
# 13  india captain harmanpreet kaur said 2023 woman...
# 14  england fast bowler chris woakes australia all...
# 15  former team india captain mahendra singh dhoni...
# 16  video rishabh pant ' speech independence day g...
# 17  english allrounder nat sciverbrunt became firs...
# 18  west ham reportedly called 30 million deal tra...
# 19  exaustralia captain ricky ponting helped austr...
# 20  secureworks said lay 15 workforce cybersecurit...
# 21  x formerly twitter started depreciating ad uni...
# 22  ' no proposal present impose import restrictio...
# 23  infosys liberty global announced fiveyear agre...
# 24  google ' indiaborn ceo sundar pichai tuesday w...
# 25  amazon device head david limp step role nearly...
# 26  apple ' iphone 14 iphone 14 pro user reporting...
# 27  paypal named software firm intuit ' senior exe...
# 28  addressing nation 77th independence day pm nar...
# 29  youth tier2 3 city writing india ' digital des...
# 30  bruce willis ' wife emma heming willis broke v...
# 31  shilpa shetty responded criticism video showed...
# 32  actress ankita lokhande latest instagram post ...
# 33  anurag kashyap talking daughter aaliyah kashya...
# 34  ' bigg bos ott 2 ' winner elvish yadav reveale...
# 35  manisha rani part ' bigg bos ott 2 ' reacted c...
# 36  actor shah rukh khan hoisted tricolour mumbai ...
# 37  according variety actress margot robbie expect...
# 38  dolly singh said always wanted become actress ...
# 39  trans actress trinetra haldar said men objecti...

# %%
prep_article_data(codeup_df, 'original', extra_words = ['ha'], exclude_words = ['no']).head()
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
#
#                                                clean  \
# 0  may traditionally known asian american pacific...
# 1  women tech panelist spotlight magdalena rahn c...
# 2  women tech panelist spotlight rachel robbinsma...
# 3  women tech panelist spotlight sarah mellor cod...
# 4  women tech panelist spotlight madeleine capper...
#
#                                              stemmed  \
# 0  may tradit known asian american pacif island a...
# 1  women tech panelist spotlight magdalena rahn c...
# 2  women tech panelist spotlight rachel robbinsma...
# 3  women tech panelist spotlight sarah mellor cod...
# 4  women tech panelist spotlight madelein capper ...
#
#                                           lemmatized
# 0  may traditionally known asian american pacific...
# 1  woman tech panelist spotlight magdalena rahn c...
# 2  woman tech panelist spotlight rachel robbinsma...
# 3  woman tech panelist spotlight sarah mellor cod...
# 4  woman tech panelist spotlight madeleine capper...

# %% [markdown]
# ### 9. Ask yourself:
#
# * If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
# * If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
# * If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?
